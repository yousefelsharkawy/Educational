# %%
import numpy as np 
import matplotlib.pyplot as plt
import cv2

# %% [markdown]
# #### Tip
# - we mainly have 2 major libraries in image processing
#     - open CV
#     - sikit image
# - we will mix between them before standerlizing cv2

# %% [markdown]
# ## jump into filtering
# - filters
#     - enhance an image
#     - emphasize or remove features
#     - smoothing
#     - sharpening
#     - edge detection

# %%
def show_image(image, title='image', cmap_type='gray'):
    plt.imshow(image ,cmap = cmap_type)
    plt.title(title)
    plt.axis('off') #we dont want axises

# %% [markdown]
# ## Edge detection
# - detect the edges by appling sobel filter

# %% [markdown]
# ### read the image

# %%
# img = cv2.imread() that was the first function to read the image, remember this read bgr
img = plt.imread('test.jpg') # this is the second function and it reads rgb

# %%
show_image(img, "people image")

# %% [markdown]
# #### from RGB to Gray

# %%
#cv2.cvtColor(image, cv2.COLOR_RGB2GRAY) this it what we took in open cv
